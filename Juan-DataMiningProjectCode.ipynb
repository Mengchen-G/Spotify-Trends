# %%
import pandas as pd
dataset = pd.read_csv("SpotifyFeatures.csv")
dataset.sort_values(by=['popularity'], ascending=False)
# Out:
#              genre            artist_name  \
# 9027         Dance          Ariana Grande
# 107804         Pop          Ariana Grande
# 86951          Rap            Post Malone
# 107803         Pop            Post Malone
# 107802         Pop          Ariana Grande
# 9026         Dance          Ariana Grande
# 66643      Hip-Hop           Daddy Yankee
# 107909         Pop           Daddy Yankee
# 138918   Reggaeton           Daddy Yankee
# 107829         Pop                Ava Max
# 86953          Rap            Post Malone
# 107875         Pop             Pedro Capó
# 92824        Indie                 Halsey
# 107812         Pop             Marshmello
# 9028         Dance                 Halsey
# 9037         Dance                Ava Max
# 107806         Pop            Post Malone
# 107810         Pop              Sam Smith
# 107808         Pop                 Halsey
# 107851         Pop               DJ Snake
# 107830         Pop              Lady Gaga
# ...

# %%
import pandas as pd
dataset = pd.read_csv("SpotifyFeatures.csv")
dataset.sort_values(by=['popularity'], ascending=False)
# Out:
#              genre            artist_name  \
# 9027         Dance          Ariana Grande
# 107804         Pop          Ariana Grande
# 86951          Rap            Post Malone
# 107803         Pop            Post Malone
# 107802         Pop          Ariana Grande
# 9026         Dance          Ariana Grande
# 66643      Hip-Hop           Daddy Yankee
# 107909         Pop           Daddy Yankee
# 138918   Reggaeton           Daddy Yankee
# 107829         Pop                Ava Max
# 86953          Rap            Post Malone
# 107875         Pop             Pedro Capó
# 92824        Indie                 Halsey
# 107812         Pop             Marshmello
# 9028         Dance                 Halsey
# 9037         Dance                Ava Max
# 107806         Pop            Post Malone
# 107810         Pop              Sam Smith
# 107808         Pop                 Halsey
# 107851         Pop               DJ Snake
# 107830         Pop              Lady Gaga
# ...

# %%
df = dataset[['popularity', 'danceability']].corr()

# %%
df
# Out:
#               popularity  danceability
# popularity      1.000000      0.256564
# danceability    0.256564      1.000000

# %%
df = dataset[['popularity', 'energy']].corr()

# %%
df
# Out:
#             popularity    energy
# popularity    1.000000  0.248922
# energy        0.248922  1.000000

# %%
df = dataset[['popularity', 'instrumentalness']].corr()
df
# Out:
#                   popularity  instrumentalness
# popularity          1.000000         -0.210983
# instrumentalness   -0.210983          1.000000

# %%
df = dataset[['popularity', 'acousticness']].corr()
df
# Out:
#               popularity  acousticness
# popularity      1.000000     -0.381295
# acousticness   -0.381295      1.000000

# %%
df = dataset[['popularity', 'loudness']].corr()
df
# Out:
#             popularity  loudness
# popularity    1.000000  0.363011
# loudness      0.363011  1.000000

# %%
df = dataset[['popularity', 'speechiness']].corr()
df
# Out:
#              popularity  speechiness
# popularity     1.000000    -0.151076
# speechiness   -0.151076     1.000000

# %%
df = dataset[['popularity', 'tempo']].corr()
df
# Out:
#             popularity     tempo
# popularity    1.000000  0.081039
# tempo         0.081039  1.000000

# %%
df = dataset[['popularity', 'valence']].corr()
df
# Out:
#             popularity   valence
# popularity    1.000000  0.060076
# valence       0.060076  1.000000

# %%
df = dataset[['popularity', 'duration_ms']].corr()
df
# Out:
#              popularity  duration_ms
# popularity     1.000000     0.002348
# duration_ms    0.002348     1.000000

# %%
df = dataset.popularity.mean()
df
# Out:
# 41.12750241701579

# %%
dataset.genre.unique()
# Out:
# array(['Movie', 'R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
ACapella = dataset[(dataset.genre == 'A Capella')]
ACapella1 = ACapella.popularity.mean()

Country = dataset[(dataset.genre == 'Country')]
Country1 = Country.popularity.mean()

Dance = dataset[(dataset.genre == 'Dance')]
Dance1 = Dance.popularity.mean()

Alternative = dataset[(dataset.genre == 'Alternative')]
Alternative1 = Alternative.popularity.mean()

Electronic = dataset[(dataset.genre == 'Electronic')]
Electronic1 = Electronic.popularity.mean()

Anime = dataset[(dataset.genre == 'Anime')]
Anime1 = Anime.popularity.mean()

Folk = dataset[(dataset.genre == 'Folk')]
Folk1 = Folk.popularity.mean()

Blues = dataset[(dataset.genre == 'Blues')]
Blues1 = Blues.popularity.mean()

Movie = dataset[(dataset.genre == 'Movie')]
Movie1 = Movie.popularity.mean()

Opera = dataset[(dataset.genre == 'Opera')]
Opera1 = Opera.popularity.mean()

HipHop = dataset[(dataset.genre == 'Hip-Hop')]
HipHop1 = HipHop.popularity.mean()

Indie = dataset[(dataset.genre == 'Indie')]
Indie1 = Indie.popularity.mean()

Jazz = dataset[(dataset.genre == 'Jazz')]
Jazz1 = Jazz.popularity.mean()

ChildrensMusic = dataset[(dataset.genre == 'Childrens Music')]
ChildrensMusic1 = ChildrensMusic.popularity.mean()

RandB = dataset[(dataset.genre == 'R&B')]
RandB1 = RandB.popularity.mean()

Classical = dataset[(dataset.genre == 'Classical')]
Classical1 = Classical.popularity.mean()

Rap = dataset[(dataset.genre == 'Rap')]
Rap1 = Rap.popularity.mean()

Comedy = dataset[(dataset.genre == 'Comedy')]
Comedy1 = Comedy.popularity.mean()

Reggae = dataset[(dataset.genre == 'Reggae')]
Reggae1 = Reggae.popularity.mean()

Pop = dataset[(dataset.genre == 'Pop')]
Pop1 = Pop.popularity.mean()

Rock = dataset[(dataset.genre == 'Rock')]
Rock1 = Rock.popularity.mean()

Reggaeton = dataset[(dataset.genre == 'Reggaeton')]
Reggaeton1 = Reggaeton.popularity.mean()

Soundtrack = dataset[(dataset.genre == 'Soundtrack')]
Soundtrack1 = Soundtrack.popularity.mean()

Soul = dataset[(dataset.genre == 'Soul')]
Soul1 = Soul.popularity.mean()

Ska = dataset[(dataset.genre == 'Ska')]
Ska1 = Ska.popularity.mean()

World = dataset[(dataset.genre == 'World')]
World1 = World.popularity.mean()


A = dataset[(dataset.key == 'A')]
A1 = A.popularity.mean()

AA = dataset[(dataset.key == 'A#')]
AA1 = AA.popularity.mean()

B = dataset[(dataset.key == 'B')]
B1 = B.popularity.mean()

BB = dataset[(dataset.key == 'B#')]
BB1 = BB.popularity.mean()

C = dataset[(dataset.key == 'C')]
C1 = C.popularity.mean()

CC = dataset[(dataset.key == 'C#')]
CC1 = CC.popularity.mean()

D = dataset[(dataset.key == 'D')]
D1 = D.popularity.mean()

DD = dataset[(dataset.key == 'D#')]
DD1 = DD.popularity.mean()

E = dataset[(dataset.key == 'E')]
E1 = E.popularity.mean()

EE = dataset[(dataset.key == 'E#')]
EE1 = EE.popularity.mean()

F = dataset[(dataset.key == 'F')]
F1 = F.popularity.mean()

FF = dataset[(dataset.key == 'F#')]
FF1 = FF.popularity.mean()

G = dataset[(dataset.key == 'G')]
G1 = G.popularity.mean()

GG = dataset[(dataset.key == 'G#')]
GG1 = GG.popularity.mean()



four = dataset[(dataset.time_signature == '4/4')]
four1 = four.popularity.mean()

three = dataset[(dataset.time_signature == '3/4')]
three1 = three.popularity.mean()

two = dataset[(dataset.time_signature == '2/4')]
two1 = two.popularity.mean()

one = dataset[(dataset.time_signature == '1/4')]
one1 = one.popularity.mean()

zero = dataset[(dataset.time_signature == '0/4')]
zero1 = zero.popularity.mean()

print()
print('Popularity mean by: Genre')
print()
print ('ACapella =', ACapella1)
print ('Country =', Country1)
print ('Dance =', Dance1)
print ('Alternative =', Alternative1)
print ('Electronic =', Electronic1)
print ('Anime =', Anime1)
print ('Folk =', Folk1)
print ('Blues =', Blues1)
print ('Movie =', Movie1)
print ('Opera =', Opera1)
print ('Hip-Hop =', HipHop1)
print ('Indie =', Indie1)
print ('Jazz =', Jazz1)
print ('Childrens Music =', ChildrensMusic1)
print ('R&B =', RandB1)
print ('Classical =', Classical1)
print ('Rap =', Rap1)
print ('Comedy =', Comedy1)
print ('Reggae =', Reggae1)
print ('Pop =', Pop1)
print ('Rock =', Rock1)
print ('Reggaeton =', Reggaeton1)
print ('Soundtrack =', Soundtrack1)
print ('Soul =', Soul1)
print ('Ska =', Ska1)
print ('World =', World1)
print()
print('Popularity mean by: Key')
print()
print ('A =', A1)
print ('A# =', AA1)
print ('B =', B1)
print ('B# =', BB1)
print ('C =', C1)
print ('C# =', CC1)
print (' =', 1)
print ('# =', 1)
print ('E =', E1)
print ('E# =', EE1)
print ('F =', F1)
print ('F# =', FF1)
print ('G =', G1)
print ('G# =', GG1)
print()
print('Popularity mean by: Time signature')
print()
print ('4/4 =', four1)
print ('3/4 =', three1)
print ('2/4 =', two1)
print ('1/4 =', one1)
print ('0/4 =', zero1)
# Out:
# Popularity mean by: Genre
#
# ACapella = 9.302521008403362
# Country = 46.100415512465375
# Dance = 57.27525571773359
# Alternative = 50.21342977437116
# Electronic = 38.05609469979738
# Anime = 24.25872873769024
# Folk = 49.94020862458329
# Blues = 34.742879308434
# Movie = 12.174096848578017
# Opera = 13.335628019323671
# Hip-Hop = 58.42313071543841
# Indie = 54.701561353871945
# Jazz = 40.82438301027434
# Childrens Music = nan
# R&B = 52.30871886120996
# Classical = 29.28219533275713
# Rap = 60.53379549393414
# Comedy = 21.342629893606034
# Reggae = 35.5893284688177
# Pop = 66.59066695077776
# Rock = 59.61939171699741
# Reggaeton = 37.742914752996526
# Soundtrack = 33.954799917064065
# Soul = 47.02783584552756
# Ska = 28.6123506874014
# World = 35.5240765171504
#
# Popularity mean by: Key
#
# A = 40.50156587711173
# A# = 40.42728326677831
# B = 43.47975765811675
# B# = nan
# C = 40.387920095711124
# C# = 43.69734063186932
#  = 1
# # = 1
# E = 40.72472685451409
# E# = nan
# ...

# %%
dataset
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
dataset.danceability.mean()
# Out:
# 0.5543644692233398

# %%
dataset.energy.mean()
# Out:
# 0.57095767347127

# %%
dataset.acousticness.mean()
# Out:
# 0.36856045175644825

# %%
dataset.liveness.mean()
# Out:
# 0.21500928452036241

# %%
dataset.instrumentalness.mean()
# Out:
# 0.1483012336397001

# %%
DanceDance = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Dance')].genre.count()
DanceDance1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Dance') & (dataset.popularity >= 41.13)].genre.count()
RatioDanceDance = DanceDance1 / DanceDance

DanceAlternative = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Alternative')].genre.count()
DanceAlternative1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Alternative') & (dataset.popularity >= 41.13)].genre.count()
RatioanceAlternative = DanceAlternative1 / 4145

DanceElectronic = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Electronic')].genre.count()
DanceElectronic1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Electronic') & (dataset.popularity >= 41.13)].genre.count()
RatioanceElectronic = DanceElectronic1 / 6416

DanceBlues = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Blues')].genre.count()
DanceBlues1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Blues') & (dataset.popularity >= 41.13)].genre.count()
RatioanceBlues = DanceBlues1 / DanceBlues

DanceCountry = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Country')].genre.count()
DanceCountry1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Country') & (dataset.popularity >= 41.13)].genre.count()
RatioanceCountry = DanceCountry1/DanceCountry

DF = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Folk')].genre.count()
DF1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Folk') & (dataset.popularity >= 41.13)].genre.count()
RDF = DF1/DF

DAn = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Anime')].genre.count()
DAn1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Anime') & (dataset.popularity >= 41.13)].genre.count()
RDAn = DAn1 / DAn

DP = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Pop')].genre.count()
DP1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Pop') & (dataset.popularity >= 41.13)].genre.count()
RDP = DP1 / DP

DS = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Soundtrack')].genre.count()
DS1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Soundtrack') & (dataset.popularity >= 41.13)].genre.count()
RDS = DS1 / DS

EAc = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'ACapella')].genre.count()
EAc1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'ACapella') & (dataset.popularity >= 41.13)].genre.count()
REAc = EAc1 / EAc

EM = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Movie')].genre.count()
EM1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Movie') & (dataset.popularity >= 41.13)].genre.count()
REM = EM1 / EM

EO = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Opera')].genre.count()
EO1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Opera') & (dataset.popularity >= 41.13)].genre.count()
REO = EO1 / EO

EH = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Hip-Hop')].genre.count()
EH1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Hip-Hop') & (dataset.popularity >= 41.13)].genre.count()
REH = EH1 / EH

EI = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Indie')].genre.count()
EI1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Indie') & (dataset.popularity >= 41.13)].genre.count()
REI = EI1 / EI

EJ = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Jazz')].genre.count()
EJ1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Jazz') & (dataset.popularity >= 41.13)].genre.count()
REJ = EJ1 / EJ

ER = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'R&B')].genre.count()
ER1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'R&B') & (dataset.popularity >= 41.13)].genre.count()
RER = ER1 / ER

ECl = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Classical')].genre.count()
ECl1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Classical') & (dataset.popularity >= 41.13)].genre.count()
RECl = ECl1 / ECl

ERa = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Rap')].genre.count()
ERa1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Rap') & (dataset.popularity >= 41.13)].genre.count()
RERa = ERa1 / ERa

ECo = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Comedy')].genre.count()
ECo1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Comedy') & (dataset.popularity >= 41.13)].genre.count()
RECo = ECo1 / ECo

ERe = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Reggae')].genre.count()
ERe1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Reggae') & (dataset.popularity >= 41.13)].genre.count()
RERe = ERe1 / ERe

ERo = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Rock')].genre.count()
ERo1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Rock') & (dataset.popularity >= 41.13)].genre.count()
RERo = ERo1 / ERo

ERg = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Reggaeton')].genre.count()
ERg1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Reggaeton') & (dataset.popularity >= 41.13)].genre.count()
RERg = ERg1 / ERg

ES = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Soul')].genre.count()
ES1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Soul') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

ESk = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Ska')].genre.count()
ESk1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'Ska') & (dataset.popularity >= 41.13)].genre.count()
RESk = ESk1 / ESk

EW = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'World')].genre.count()
EW1 = dataset[(dataset.danceability >= 0.56) & (dataset.genre == 'World') & (dataset.popularity >= 41.13)].genre.count()
REW = EW1 / EW




print('Chances a song is popular when high danceability is combined with:')
print('Dance:', RatioDanceDance)
print('Alternative', RatioanceAlternative)
print('Electronic', RatioanceElectronic)
print('Blues', RatioanceBlues)
print('Country', RatioanceCountry)
print('Folk', RDF)
print('Anime', RDAn)
print('Pop', RDP)
print('ACapella', REAc)
print('Movie', REM)
print('Opera', REO)
print('Hip-Hop', REH)
print('Indie', REI)
print('Jazz', REJ)
print('R&B', RER)
print('Classical', RECl)
print('Rap', RERa)
print('Comedy', RECo)
print('Reggae', RERe)
print('Rock', RERo)
print('Reggaeton', RERg)
print('Soul', RES)
print('Ska', RESk)
print('World', REW)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in long_scalars
# Chances a song is popular when high danceability is combined with:
# Dance: 0.9788840937114673
# Alternative 0.9061519903498191
# Electronic 0.3394638403990025
# Blues 0.19023878247179218
# Country 0.648643216080402
# Folk 0.8804597701149425
# Anime 0.05453177886423467
# Pop 0.9961600945207503
# ACapella nan
# Movie 0.02341688654353562
# Opera 0.0
# Hip-Hop 0.9960346964064436
# Indie 0.9892093388267609
# Jazz 0.45617205855774445
# R&B 0.9240371441619729
# Classical 0.17559523809523808
# Rap 0.9972328370009224
# Comedy 0.023028326879967392
# Reggae 0.27224993436597533
# Rock 0.9933349202570817
# Reggaeton 0.3422116527942925
# Soul 0.728446884081369
# Ska 0.18432550518842164
# World 0.19258920402561758

# %%
ED = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Dance')].genre.count()
ED1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Dance') & (dataset.popularity >= 41.13)].genre.count()
RED = ED1 / ED

EA = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Alternative')].genre.count()
EA1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Alternative') & (dataset.popularity >= 41.13)].genre.count()
REA = EA1/EA

EE = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Electronic')].genre.count()
EE1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Electronic') & (dataset.popularity >= 41.13)].genre.count()
REE = EE1 / EE

EB = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Blues')].genre.count()
EB1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Blues') & (dataset.popularity >= 41.13)].genre.count()
REB = EB1 / EB

EC = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Country')].genre.count()
EC1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Country') & (dataset.popularity >= 41.13)].genre.count()
REC = EC1/EC

EF = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Folk')].genre.count()
EF1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Folk') & (dataset.popularity >= 41.13)].genre.count()
REF = EF1/EF

EAn = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Anime')].genre.count()
EAn1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Anime') & (dataset.popularity >= 41.13)].genre.count()
REAn = EAn1 / EAn

EP = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Pop')].genre.count()
EP1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Pop') & (dataset.popularity >= 41.13)].genre.count()
REP = EP1 / EP

ES = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Soundtrack')].genre.count()
ES1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Soundtrack') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

EAc = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'ACapella')].genre.count()
EAc1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'ACapella') & (dataset.popularity >= 41.13)].genre.count()
REAc = EAc1 / EAc

EM = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Movie')].genre.count()
EM1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Movie') & (dataset.popularity >= 41.13)].genre.count()
REM = EM1 / EM

EO = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Opera')].genre.count()
EO1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Opera') & (dataset.popularity >= 41.13)].genre.count()
REO = EO1 / EO

EH = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Hip-Hop')].genre.count()
EH1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Hip-Hop') & (dataset.popularity >= 41.13)].genre.count()
REH = EH1 / EH

EI = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Indie')].genre.count()
EI1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Indie') & (dataset.popularity >= 41.13)].genre.count()
REI = EI1 / EI

EJ = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Jazz')].genre.count()
EJ1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Jazz') & (dataset.popularity >= 41.13)].genre.count()
REJ = EJ1 / EJ

ER = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'R&B')].genre.count()
ER1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'R&B') & (dataset.popularity >= 41.13)].genre.count()
RER = ER1 / ER

ECl = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Classical')].genre.count()
ECl1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Classical') & (dataset.popularity >= 41.13)].genre.count()
RECl = ECl1 / ECl

ERa = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Rap')].genre.count()
ERa1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Rap') & (dataset.popularity >= 41.13)].genre.count()
RERa = ERa1 / ERa

ECo = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Comedy')].genre.count()
ECo1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Comedy') & (dataset.popularity >= 41.13)].genre.count()
RECo = ECo1 / ECo

ERe = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Reggae')].genre.count()
ERe1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Reggae') & (dataset.popularity >= 41.13)].genre.count()
RERe = ERe1 / ERe

ERo = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Rock')].genre.count()
ERo1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Rock') & (dataset.popularity >= 41.13)].genre.count()
RERo = ERo1 / ERo

ERg = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Reggaeton')].genre.count()
ERg1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Reggaeton') & (dataset.popularity >= 41.13)].genre.count()
RERg = ERg1 / ERg

ES = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Soul')].genre.count()
ES1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Soul') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

ESk = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Ska')].genre.count()
ESk1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'Ska') & (dataset.popularity >= 41.13)].genre.count()
RESk = ESk1 / ESk

EW = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'World')].genre.count()
EW1 = dataset[(dataset.energy >= 0.57) & (dataset.genre == 'World') & (dataset.popularity >= 41.13)].genre.count()
REW = EW1 / EW

print('Chances a song is popular when high energy is combined with:')
print('Dance:', RED)
print('Alternative:', REA)
print('Electronic:', REE)
print('Blues:', REB)
print('Country:', REC)
print('Folk:', REF)
print('Anime:', REAn)
print('Pop:', REP)
print('Soundtrack:', RDS)
print('ACapella:', REAc)
print('Movie:', REM)
print('Opera:', REO)
print('Hip-Hop:', REH)
print('Indie:', REI)
print('Jazz:', REJ)
print('R&B:', RER)
print('Classical:', RECl)
print('Rap:', RERa)
print('Comedy:', RECo)
print('Reggae:', RERe)
print('Rock:', RERo)
print('Reggaeton:', RERg)
print('Soul:', RES)
print('Ska:', RESk)
print('World:', REW)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in long_scalars
# Chances a song is popular when high energy is combined with:
# Dance: 0.9772287542789105
# Alternative: 0.9127145766656968
# Electronic: 0.32482970482169093
# Blues: 0.20282016611937415
# Country: 0.6504093983624065
# Folk: 0.8908062234794908
# Anime: 0.07129614023259734
# Pop: 0.9959974383605508
# Soundtrack: 0.126232741617357
# ACapella: nan
# Movie: 0.02510460251046025
# Opera: 0.0
# Hip-Hop: 0.9957359444093493
# Indie: 0.9923723841189126
# Jazz: 0.41707812953819345
# R&B: 0.928016453382084
# Classical: 0.3220588235294118
# Rap: 0.9970083451424973
# Comedy: 0.032581079061425794
# Reggae: 0.27286742034943473
# Rock: 0.9934259674286569
# Reggaeton: 0.33370535714285715
# Soul: 0.7302494802494802
# Ska: 0.1298950601484515
# World: 0.23260538344337228

# %%
ED = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Dance')].genre.count()
ED1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Dance') & (dataset.popularity >= 41.13)].genre.count()
RED = ED1 / ED

EA = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Alternative')].genre.count()
EA1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Alternative') & (dataset.popularity >= 41.13)].genre.count()
REA = EA1/EA

EE = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Electronic')].genre.count()
EE1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Electronic') & (dataset.popularity >= 41.13)].genre.count()
REE = EE1 / EE

EB = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Blues')].genre.count()
EB1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Blues') & (dataset.popularity >= 41.13)].genre.count()
REB = EB1 / EB

EC = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Country')].genre.count()
EC1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Country') & (dataset.popularity >= 41.13)].genre.count()
REC = EC1/EC

EF = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Folk')].genre.count()
EF1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Folk') & (dataset.popularity >= 41.13)].genre.count()
REF = EF1/EF

EAn = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Anime')].genre.count()
EAn1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Anime') & (dataset.popularity >= 41.13)].genre.count()
REAn = EAn1 / EAn

EP = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Pop')].genre.count()
EP1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Pop') & (dataset.popularity >= 41.13)].genre.count()
REP = EP1 / EP

ES = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Soundtrack')].genre.count()
ES1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Soundtrack') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

EAc = dataset[(dataset.energy >= 0.37) & (dataset.genre == 'ACapella')].genre.count()
EAc1 = dataset[(dataset.energy >= 0.37) & (dataset.genre == 'ACapella') & (dataset.popularity >= 41.13)].genre.count()
REAc = EAc1 / EAc

EM = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Movie')].genre.count()
EM1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Movie') & (dataset.popularity >= 41.13)].genre.count()
REM = EM1 / EM

EO = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Opera')].genre.count()
EO1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Opera') & (dataset.popularity >= 41.13)].genre.count()
REO = EO1 / EO

EH = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Hip-Hop')].genre.count()
EH1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Hip-Hop') & (dataset.popularity >= 41.13)].genre.count()
REH = EH1 / EH

EI = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Indie')].genre.count()
EI1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Indie') & (dataset.popularity >= 41.13)].genre.count()
REI = EI1 / EI

EJ = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Jazz')].genre.count()
EJ1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Jazz') & (dataset.popularity >= 41.13)].genre.count()
REJ = EJ1 / EJ

ER = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'R&B')].genre.count()
ER1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'R&B') & (dataset.popularity >= 41.13)].genre.count()
RER = ER1 / ER

ECl = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Classical')].genre.count()
ECl1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Classical') & (dataset.popularity >= 41.13)].genre.count()
RECl = ECl1 / ECl

ERa = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Rap')].genre.count()
ERa1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Rap') & (dataset.popularity >= 41.13)].genre.count()
RERa = ERa1 / ERa

ECo = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Comedy')].genre.count()
ECo1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Comedy') & (dataset.popularity >= 41.13)].genre.count()
RECo = ECo1 / ECo

ERe = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Reggae')].genre.count()
ERe1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Reggae') & (dataset.popularity >= 41.13)].genre.count()
RERe = ERe1 / ERe

ERo = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Rock')].genre.count()
ERo1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Rock') & (dataset.popularity >= 41.13)].genre.count()
RERo = ERo1 / ERo

ERg = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Reggaeton')].genre.count()
ERg1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Reggaeton') & (dataset.popularity >= 41.13)].genre.count()
RERg = ERg1 / ERg

ES = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Soul')].genre.count()
ES1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Soul') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

ESk = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Ska')].genre.count()
ESk1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'Ska') & (dataset.popularity >= 41.13)].genre.count()
RESk = ESk1 / ESk

EW = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'World')].genre.count()
EW1 = dataset[(dataset.acousticness >= 0.37) & (dataset.genre == 'World') & (dataset.popularity >= 41.13)].genre.count()
REW = EW1 / EW

print('Chances a song is popular when high acousticness is combined with:')
print('Dance:', RED)
print('Alternative:', REA)
print('Electronic:', REE)
print('Blues:', REB)
print('Country:', REC)
print('Folk:', REF)
print('Anime:', REAn)
print('Pop:', REP)
print('Soundtrack:', RDS)
print('ACapella:', REAc)
print('Movie:', REM)
print('Opera:', REO)
print('Hip-Hop:', REH)
print('Indie:', REI)
print('Jazz:', REJ)
print('R&B:', RER)
print('Classical:', RECl)
print('Rap:', RERa)
print('Comedy:', RECo)
print('Reggae:', RERe)
print('Rock:', RERo)
print('Reggaeton:', RERg)
print('Soul:', RES)
print('Ska:', RESk)
print('World:', REW)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in long_scalars
# Chances a song is popular when high acousticness is combined with:
# Dance: 0.9883512544802867
# Alternative: 0.9341614906832298
# Electronic: 0.3234732824427481
# Blues: 0.19124293785310734
# Country: 0.635
# Folk: 0.8633648101753709
# Anime: 0.026949335249730505
# Pop: 0.9981884057971014
# Soundtrack: 0.126232741617357
# ACapella: nan
# Movie: 0.039203768424251634
# Opera: 0.008454106280193236
# Hip-Hop: 1.0
# Indie: 0.9912376779846659
# Jazz: 0.4462998769555282
# R&B: 0.9028629856850716
# Classical: 0.14011471380077256
# Rap: 0.9962880475129918
# Comedy: 0.02469396369776277
# Reggae: 0.25526137135098437
# Rock: 0.9933571793561574
# Reggaeton: 0.33524684270952926
# Soul: 0.6972547025927809
# Ska: 0.1167076167076167
# World: 0.22330333252250062

# %%
ED = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Dance')].genre.count()
ED1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Dance') & (dataset.popularity >= 41.13)].genre.count()
RED = ED1 / ED

EA = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Alternative')].genre.count()
EA1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Alternative') & (dataset.popularity >= 41.13)].genre.count()
REA = EA1/EA

EE = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Electronic')].genre.count()
EE1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Electronic') & (dataset.popularity >= 41.13)].genre.count()
REE = EE1 / EE

EB = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Blues')].genre.count()
EB1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Blues') & (dataset.popularity >= 41.13)].genre.count()
REB = EB1 / EB

EC = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Country')].genre.count()
EC1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Country') & (dataset.popularity >= 41.13)].genre.count()
REC = EC1/EC

EF = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Folk')].genre.count()
EF1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Folk') & (dataset.popularity >= 41.13)].genre.count()
REF = EF1/EF

EAn = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Anime')].genre.count()
EAn1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Anime') & (dataset.popularity >= 41.13)].genre.count()
REAn = EAn1 / EAn

EP = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Pop')].genre.count()
EP1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Pop') & (dataset.popularity >= 41.13)].genre.count()
REP = EP1 / EP

ES = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Soundtrack')].genre.count()
ES1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Soundtrack') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

EAc = dataset[(dataset.energy >= 0.59) & (dataset.genre == 'ACapella')].genre.count()
EAc1 = dataset[(dataset.energy >= 0.59) & (dataset.genre == 'ACapella') & (dataset.popularity >= 41.13)].genre.count()
REAc = EAc1 / EAc

EM = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Movie')].genre.count()
EM1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Movie') & (dataset.popularity >= 41.13)].genre.count()
REM = EM1 / EM

EO = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Opera')].genre.count()
EO1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Opera') & (dataset.popularity >= 41.13)].genre.count()
REO = EO1 / EO

EH = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Hip-Hop')].genre.count()
EH1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Hip-Hop') & (dataset.popularity >= 41.13)].genre.count()
REH = EH1 / EH

EI = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Indie')].genre.count()
EI1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Indie') & (dataset.popularity >= 41.13)].genre.count()
REI = EI1 / EI

EJ = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Jazz')].genre.count()
EJ1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Jazz') & (dataset.popularity >= 41.13)].genre.count()
REJ = EJ1 / EJ

ER = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'R&B')].genre.count()
ER1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'R&B') & (dataset.popularity >= 41.13)].genre.count()
RER = ER1 / ER

ECl = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Classical')].genre.count()
ECl1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Classical') & (dataset.popularity >= 41.13)].genre.count()
RECl = ECl1 / ECl

ERa = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Rap')].genre.count()
ERa1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Rap') & (dataset.popularity >= 41.13)].genre.count()
RERa = ERa1 / ERa

ECo = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Comedy')].genre.count()
ECo1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Comedy') & (dataset.popularity >= 41.13)].genre.count()
RECo = ECo1 / ECo

ERe = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Reggae')].genre.count()
ERe1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Reggae') & (dataset.popularity >= 41.13)].genre.count()
RERe = ERe1 / ERe

ERo = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Rock')].genre.count()
ERo1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Rock') & (dataset.popularity >= 41.13)].genre.count()
RERo = ERo1 / ERo

ERg = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Reggaeton')].genre.count()
ERg1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Reggaeton') & (dataset.popularity >= 41.13)].genre.count()
RERg = ERg1 / ERg

ES = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Soul')].genre.count()
ES1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Soul') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

ESk = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Ska')].genre.count()
ESk1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'Ska') & (dataset.popularity >= 41.13)].genre.count()
RESk = ESk1 / ESk

EW = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'World')].genre.count()
EW1 = dataset[(dataset.instrumentalness >= 0.22) & (dataset.genre == 'World') & (dataset.popularity >= 41.13)].genre.count()
REW = EW1 / EW

print('Chances a song is popular when high liveness is combined with:')
print('Dance:', RED)
print('Alternative:', REA)
print('Electronic:', REE)
print('Blues:', REB)
print('Country:', REC)
print('Folk:', REF)
print('Anime:', REAn)
print('Pop:', REP)
print('Soundtrack:', RDS)
print('ACapella:', REAc)
print('Movie:', REM)
print('Opera:', REO)
print('Hip-Hop:', REH)
print('Indie:', REI)
print('Jazz:', REJ)
print('R&B:', RER)
print('Classical:', RECl)
print('Rap:', RERa)
print('Comedy:', RECo)
print('Reggae:', RERe)
print('Rock:', RERo)
print('Reggaeton:', RERg)
print('Soul:', RES)
print('Ska:', RESk)
print('World:', REW)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: invalid value encountered in long_scalars
# Chances a song is popular when high liveness is combined with:
# Dance: 0.9651972157772621
# Alternative: 0.9021479713603818
# Electronic: 0.2868780273007486
# Blues: 0.1594090202177294
# Country: 0.7
# Folk: 0.8722659667541557
# Anime: 0.01596611274030629
# Pop: 0.9952380952380953
# Soundtrack: 0.126232741617357
# ACapella: nan
# Movie: 0.0348297213622291
# Opera: 0.012815378454144974
# Hip-Hop: 0.9932885906040269
# Indie: 0.9941715237302248
# Jazz: 0.3665992357833221
# R&B: 0.8821752265861027
# Classical: 0.15131773763695588
# Rap: 1.0
# Comedy: 0.0
# Reggae: 0.1746987951807229
# Rock: 0.99860529986053
# Reggaeton: 0.2972972972972973
# Soul: 0.7358722358722358
# Ska: 0.09375
# World: 0.17469418960244648

# %%
ED = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Dance')].genre.count()
ED1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Dance') & (dataset.popularity >= 41.13)].genre.count()
RED = ED1 / ED

EA = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Alternative')].genre.count()
EA1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Alternative') & (dataset.popularity >= 41.13)].genre.count()
REA = EA1/EA

EE = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Electronic')].genre.count()
EE1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Electronic') & (dataset.popularity >= 41.13)].genre.count()
REE = EE1 / EE

EB = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Blues')].genre.count()
EB1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Blues') & (dataset.popularity >= 41.13)].genre.count()
REB = EB1 / EB

EC = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Country')].genre.count()
EC1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Country') & (dataset.popularity >= 41.13)].genre.count()
REC = EC1/EC

EF = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Folk')].genre.count()
EF1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Folk') & (dataset.popularity >= 41.13)].genre.count()
REF = EF1/EF

EAn = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Anime')].genre.count()
EAn1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Anime') & (dataset.popularity >= 41.13)].genre.count()
REAn = EAn1 / EAn

EP = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Pop')].genre.count()
EP1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Pop') & (dataset.popularity >= 41.13)].genre.count()
REP = EP1 / EP

ES = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Soundtrack')].genre.count()
ES1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Soundtrack') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

EAc = dataset[(dataset.energy >= 0.59) & (dataset.genre == 'ACapella')].genre.count()
EAc1 = dataset[(dataset.energy >= 0.59) & (dataset.genre == 'ACapella') & (dataset.popularity >= 41.13)].genre.count()
REAc = EAc1 / EAc

EM = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Movie')].genre.count()
EM1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Movie') & (dataset.popularity >= 41.13)].genre.count()
REM = EM1 / EM

EO = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Opera')].genre.count()
EO1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Opera') & (dataset.popularity >= 41.13)].genre.count()
REO = EO1 / EO

EH = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Hip-Hop')].genre.count()
EH1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Hip-Hop') & (dataset.popularity >= 41.13)].genre.count()
REH = EH1 / EH

EI = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Indie')].genre.count()
EI1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Indie') & (dataset.popularity >= 41.13)].genre.count()
REI = EI1 / EI

EJ = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Jazz')].genre.count()
EJ1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Jazz') & (dataset.popularity >= 41.13)].genre.count()
REJ = EJ1 / EJ

ER = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'R&B')].genre.count()
ER1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'R&B') & (dataset.popularity >= 41.13)].genre.count()
RER = ER1 / ER

ECl = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Classical')].genre.count()
ECl1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Classical') & (dataset.popularity >= 41.13)].genre.count()
RECl = ECl1 / ECl

ERa = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Rap')].genre.count()
ERa1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Rap') & (dataset.popularity >= 41.13)].genre.count()
RERa = ERa1 / ERa

ECo = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Comedy')].genre.count()
ECo1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Comedy') & (dataset.popularity >= 41.13)].genre.count()
RECo = ECo1 / ECo

ERe = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Reggae')].genre.count()
ERe1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Reggae') & (dataset.popularity >= 41.13)].genre.count()
RERe = ERe1 / ERe

ERo = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Rock')].genre.count()
ERo1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Rock') & (dataset.popularity >= 41.13)].genre.count()
RERo = ERo1 / ERo

ERg = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Reggaeton')].genre.count()
ERg1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Reggaeton') & (dataset.popularity >= 41.13)].genre.count()
RERg = ERg1 / ERg

ES = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Soul')].genre.count()
ES1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Soul') & (dataset.popularity >= 41.13)].genre.count()
RES = ES1 / ES

ESk = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Ska')].genre.count()
ESk1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'Ska') & (dataset.popularity >= 41.13)].genre.count()
RESk = ESk1 / ESk

EW = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'World')].genre.count()
EW1 = dataset[(dataset.instrumentalness >= 0.15) & (dataset.genre == 'World') & (dataset.popularity >= 41.13)].genre.count()
REW = EW1 / EW

print('Chances a song is popular when high instrumentalness is combined with:')
print('Dance:', RED)
print('Alternative:', REA)
print('Electronic:', REE)
print('Blues:', REB)
print('Country:', REC)
print('Folk:', REF)
print('Anime:', REAn)
print('Pop:', REP)
print('Soundtrack:', RDS)
print('ACapella:', REAc)
print('Movie:', REM)
print('Opera:', REO)
print('Hip-Hop:', REH)
print('Indie:', REI)
print('Jazz:', REJ)
print('R&B:', RER)
print('Classical:', RECl)
print('Rap:', RERa)
print('Comedy:', RECo)
print('Reggae:', RERe)
print('Rock:', RERo)
print('Reggaeton:', RERg)
print('Soul:', RES)
print('Ska:', RESk)
print('World:', REW)
# Out:
# /home/user/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in long_scalars
# Chances a song is popular when high instrumentalness is combined with:
# Dance: 0.964
# Alternative: 0.9065040650406504
# Electronic: 0.2885673527613613
# Blues: 0.16488651535380508
# Country: 0.6931818181818182
# Folk: 0.8736842105263158
# Anime: 0.016403785488958992
# Pop: 0.9961977186311787
# Soundtrack: 0.126232741617357
# ACapella: nan
# Movie: 0.03468634686346864
# Opera: 0.012762762762762763
# Hip-Hop: 0.9947368421052631
# Indie: 0.9935805991440799
# Jazz: 0.3712137486573577
# R&B: 0.8985148514851485
# Classical: 0.15098152424942263
# Rap: 1.0
# Comedy: 0.0
# Reggae: 0.18685121107266436
# Rock: 0.9976470588235294
# Reggaeton: 0.3064516129032258
# Soul: 0.7317327766179541
# Ska: 0.09479768786127167
# World: 0.17317612380250552

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
dataset1 = pd.read_csv("SpotifyAudioFeaturesNov2018.csv")
dataset2 = pd.read_csv("SpotifyAudioFeaturesApril2019.csv")

# %%
import pandas as pd
import numpy as np

data1 = pd.read_csv("SpotifyAudioFeaturesNov2018.csv")
df = pd.DataFrame(data1)


sns.heatmap(df.corr(),cmap="YlOrRd")

# %%
data2 = pd.read_csv("SpotifyAudioFeaturesApril2019.csv")
df2 = pd.DataFrame(data2)


sns.heatmap(df2.corr(),cmap="YlOrRd")

# %%
dataset1 = pd.read_csv("SpotifyAudioFeaturesNov2018.csv")
df =dataset1.popularity.mean()
df
# Out:
# 24.23508232220809

# %%
dataset2 = pd.read_csv("SpotifyAudioFeaturesApril2019.csv")
df =dataset2.popularity.mean()
df
# Out:
# 24.20898800731653

# %%
dataset1.plot.scatter(y='popularity', x='acousticness', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='acousticness', alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='danceability', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='danceability', alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='energy', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='energy',alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='instrumentalness', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='instrumentalness', alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='liveness', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='liveness', alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='loudness', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='loudness', alpha = 0.01)
dataset1.plot.scatter(y='popularity', x='speechiness', alpha = 0.01)
dataset2.plot.scatter(y='popularity', x='speechiness', alpha = 0.01)

# %%
dataset1.boxplot(column=['popularity'], by= 'mode')
dataset1.boxplot(column=['popularity'], by= 'time_signature')
dataset1.boxplot(column=['popularity'], by= 'key')
dataset2.boxplot(column=['popularity'], by= 'mode')
dataset2.boxplot(column=['popularity'], by= 'time_signature')
dataset2.boxplot(column=['popularity'], by= 'key')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_iris
# %matplotlib inline
dataset1 = pd.read_csv("top2017.csv")
dataset2 = pd.read_csv("top2018.csv")

NewDataset = pd.read_csv("SpotifyFeatures.csv")
test= pd.read_csv("top2019.csv")
test1 = test[['Unnamed: 1', 'Unnamed: 2']]
dataset33 = NewDataset[NewDataset['track_name'].isin(test1['Unnamed: 1']) & NewDataset['artist_name'].isin(test1['Unnamed: 2'])]
dataset33.rename(columns={'track_name':'name', 'artist_name':'artists'}, inplace=True)
dataset3 = dataset33.head(100)


test22 = pd.read_csv("top2016.csv")
test2 = test22[['Unnamed: 1', 'Unnamed: 2']]
dataset00 = NewDataset[NewDataset['track_name'].isin(test2['Unnamed: 1']) & NewDataset['artist_name'].isin(test2['Unnamed: 2'])]
dataset00.rename(columns={'track_name':'name', 'artist_name':'artists'}, inplace=True)
dataset0 = dataset00.head(100)

# %%
df = pd.DataFrame(dataset0)

sns.heatmap(df.corr(),cmap="YlOrRd")

# %%
df = pd.DataFrame(dataset1)

sns.heatmap(df.corr(),cmap="YlOrRd")

# %%
df = pd.DataFrame(dataset2)

sns.heatmap(df.corr(),cmap="YlOrRd")

# %%
df = pd.DataFrame(dataset3)

sns.heatmap(df.corr(),cmap="YlOrRd")

# %%
CommonHits01 = pd.merge(dataset0, dataset1, how='inner', on=['name'])
CommonUnique01 = CommonHits01.name.unique()

CommonHits12 = pd.merge(dataset1, dataset2, how='inner', on=['name'])
CommonUnique12 = CommonHits12.name.unique()

CommonHits23 = pd.merge(dataset2, dataset3, how='inner', on=['name'])
CommonUnique23 = CommonHits23.name.unique()

OldHits2016 = dataset0[~dataset0['name'].isin(CommonUnique01)]
OldHits2017 = dataset1[~dataset1['name'].isin(CommonUnique12)]
NewHits2018 = dataset2[~dataset2['name'].isin(CommonUnique12)]
NewHits2019 = dataset3[~dataset3['name'].isin(CommonUnique23)]

# %%
OldHits2016['artists'].value_counts().head(16)
# Out:
# Zara Larsson        5
# Shawn Mendes        4
# Alessia Cara        3
# Jonas Blue          3
# Rihanna             3
# Justin Bieber       3
# J. Cole             3
# The Chainsmokers    3
# Ariana Grande       3
# Britney Spears      2
# Calvin Harris       2
# George Michael      2
# DJ Snake            2
# Chuck Berry         2
# Cheat Codes         2
# Sia                 2
# Name: artists, dtype: int64

# %%
OldHits2017['artists'].value_counts().head(11)
# Out:
# The Chainsmokers    4
# Martin Garrix       3
# Drake               3
# Bruno Mars          2
# The Weeknd          2
# Luis Fonsi          2
# Calvin Harris       2
# Maroon 5            2
# DJ Khaled           2
# Ed Sheeran          2
# Clean Bandit        2
# Name: artists, dtype: int64

# %%
NewHits2018['artists'].value_counts().head(11)
# Out:
# XXXTENTACION     6
# Post Malone      5
# Drake            4
# Selena Gomez     2
# Clean Bandit     2
# Calvin Harris    2
# The Weeknd       2
# Marshmello       2
# Maroon 5         2
# Migos            2
# Ariana Grande    2
# Name: artists, dtype: int64

# %%
NewHits2019['artists'].value_counts().head(13)
# Out:
# Ariana Grande       8
# Why Don't We        3
# Luis Fonsi          2
# Bebe Rexha          2
# DJ Snake            2
# Lady Gaga           2
# The Chainsmokers    2
# J. Cole             2
# Ava Max             2
# ChocQuibTown        2
# Daddy Yankee        2
# Shawn Mendes        2
# Lil Baby            2
# Name: artists, dtype: int64

# %%
D0 = OldHits2016.danceability.mean()
D1 = OldHits2017.danceability.mean()
D2 = NewHits2018.danceability.mean()
D3 = NewHits2019.danceability.mean()

E0 = OldHits2016.energy.mean()
E1 = OldHits2017.energy.mean()
E2 = NewHits2018.energy.mean()
E3 = NewHits2019.energy.mean()

L0 = OldHits2016.loudness.mean()
L1 = OldHits2017.loudness.mean()
L2 = NewHits2018.loudness.mean()
L3 = NewHits2019.loudness.mean()

Li0 = OldHits2016.liveness.mean()
Li1 = OldHits2017.liveness.mean()
Li2 = NewHits2018.liveness.mean()
Li3 = NewHits2019.liveness.mean()

S0 = OldHits2016.speechiness.mean()
S1 = OldHits2017.speechiness.mean()
S2 = NewHits2018.speechiness.mean()
S3 = NewHits2019.speechiness.mean()

A0 = OldHits2016.speechiness.mean()
A1 = OldHits2017.acousticness.mean()
A2 = NewHits2018.acousticness.mean()
A3 = NewHits2019.acousticness.mean()

I0 = OldHits2016.instrumentalness.mean()
I1 = OldHits2017.instrumentalness.mean()
I2 = NewHits2018.instrumentalness.mean()
I3 = NewHits2019.instrumentalness.mean()

print("Old danceability:",D0)
print("Old danceability:",D1)
print("New danceability:",D2)
print("New danceability:",D3)
print("")

print("Old energy:",E0)
print("Old energy:",E1)
print("New energy:",E2)
print("New energy:",E3)
print("")

print("Old loudness:",L0)
print("Old loudness:",L1)
print("New loudness:",L2)
print("New loudness:",L3)
print("")

print("Old liveness:",Li0)
print("Old liveness:",Li1)
print("New liveness:",Li2)
print("New liveness:",Li3)
print("")

print("Old speechiness:",S0)
print("Old speechiness:",S1)
print("New speechiness:",S2)
print("New speechiness:",S3)
print("")

print("Old acousticness:",A0)
print("Old acousticness:",A1)
print("New acousticness:",A2)
print("New acousticness:",A3)
print("")

print("Old instrumentalness:",I0)
print("Old instrumentalness:",I1)
print("New instrumentalness:",I2)
print("New instrumentalness:",I3)
# Out:
# Old danceability: 0.6457625000000001
# Old danceability: 0.6982674418604652
# New danceability: 0.7211395348837205
# New danceability: 0.7123970588235295
#
# Old energy: 0.6746875000000002
# Old energy: 0.6670813953488371
# New energy: 0.6649883720930233
# New energy: 0.6406617647058824
#
# Old loudness: -6.2749749999999995
# Old loudness: -5.660174418604649
# New loudness: -5.6928372093023265
# New loudness: -5.6625147058823515
#
# Old liveness: 0.1565225
# Old liveness: 0.15287209302325583
# New liveness: 0.16211976744186046
# New liveness: 0.17674411764705883
#
# Old speechiness: 0.09962374999999994
# Old speechiness: 0.10705581395348839
# New speechiness: 0.12028488372093026
# New speechiness: 0.1289132352941177
#
# Old acousticness: 0.09962374999999994
# Old acousticness: 0.15924372093023265
# New acousticness: 0.19313593023255807
# New acousticness: 0.20430617647058824
#
# Old instrumentalness: 0.00532941575
# Old instrumentalness: 0.0031339654651162795
# ...

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['danceability'],hist=False,kde=True, label='2016'); sns.distplot(OldHits2017['danceability'],hist=False,kde=True, label='2017', axlabel='2017'); sns.distplot(NewHits2018['danceability'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['danceability'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['energy'],hist=False,kde=True, label='2016');sns.distplot(OldHits2017['energy'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['energy'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['energy'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['loudness'],hist=False,kde=True, label='2016');sns.distplot(OldHits2017['loudness'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['loudness'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['loudness'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['liveness'],hist=False,kde=True, label='2016');sns.distplot(OldHits2017['liveness'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['liveness'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['liveness'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['speechiness'],hist=False,kde=True, label='2016');sns.distplot(OldHits2017['speechiness'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['speechiness'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['speechiness'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2016['acousticness'],hist=False,kde=True, label='2016');sns.distplot(OldHits2017['acousticness'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['acousticness'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['acousticness'],hist=False,kde=True,label='2019')

# %%
sns.set_style(style='darkgrid')
sns.distplot(OldHits2017['instrumentalness'],hist=False,kde=True, label='2017'); sns.distplot(NewHits2018['instrumentalness'],hist=False,kde=True,label='2018'); sns.distplot(NewHits2019['instrumentalness'],hist=False,kde=True,label='2019')

# %%
print("Drake")
OldDrake = OldHits2017[OldHits2017['artists'].str.match('Drake')]
NewDrake = NewHits2018[NewHits2018['artists'].str.match('Drake')]
D1 = OldDrake.danceability.mean()
D2 = NewDrake.danceability.mean()
E1 = OldDrake.energy.mean()
E2 = NewDrake.energy.mean()
L1 = OldDrake.loudness.mean()
L2 = NewDrake.loudness.mean()
Li1 = OldDrake.liveness.mean()
Li2 = NewDrake.liveness.mean()
S1 = OldDrake.speechiness.mean()
S2 = NewDrake.speechiness.mean()
A1 = OldDrake.acousticness.mean()
A2 = NewDrake.acousticness.mean()
I1 = OldDrake.instrumentalness.mean()
I2 = NewDrake.instrumentalness.mean()

if(D1<D2):
    print("Danceability match: True")
else:
    print("Danceability match: False")

if(E1>E2):
    print("energy match: True")
else:
    print("energy match: False")

if(L1>L2):
    print("Loudness match: True")
else:
    print("Loudness match: False")

if(Li1<Li2):
    print("Liveness match: True")
else:
    print("Liveness match: False")
    
if(S1<S2):
    print("Speechiness match: True")
else:
    print("Speechiness match: False")
    
if(A1<A2):
    print("Acousticness match: True")
else:
    print("Acousticness match: False")
    
if(I1>I2):
    print("Instrumentalness match: True")
else:
    print("Instrumentalness match: False")
    
print("")
print("")

print("Maroon 5")
OldM5 = OldHits2017[OldHits2017['artists'].str.match('Maroon 5')]
NewM5 = NewHits2018[NewHits2018['artists'].str.match('Maroon 5')]
D1 = OldM5.danceability.mean()
D2 = NewM5.danceability.mean()
E1 = OldM5.energy.mean()
E2 = NewM5.energy.mean()
L1 = OldM5.loudness.mean()
L2 = NewM5.loudness.mean()
Li1 = OldM5.liveness.mean()
Li2 = NewM5.liveness.mean()
S1 = OldM5.speechiness.mean()
S2 = NewM5.speechiness.mean()
A1 = OldM5.acousticness.mean()
A2 = NewM5.acousticness.mean()
I1 = OldM5.instrumentalness.mean()
I2 = NewM5.instrumentalness.mean()

if(D1<D2):
    print("Danceability match: True")
else:
    print("Danceability match: False")

if(E1>E2):
    print("energy match: True")
else:
    print("energy match: False")

if(L1>L2):
    print("Loudness match: True")
else:
    print("Loudness match: False")

if(Li1<Li2):
    print("Liveness match: True")
else:
    print("Liveness match: False")
    
if(S1<S2):
    print("Speechiness match: True")
else:
    print("Speechiness match: False")
    
if(A1<A2):
    print("Acousticness match: True")
else:
    print("Acousticness match: False")
    
if(I1>I2):
    print("Instrumentalness match: True")
else:
    print("Instrumentalness match: False")

print("")
print("")

print("Calvin Harris")
OldC = OldHits2017[OldHits2017['artists'].str.match('Calvin Harris')]
NewC = NewHits2018[NewHits2018['artists'].str.match('Calvin Harris')]
D1 = OldC.danceability.mean()
D2 = NewC.danceability.mean()
E1 = OldC.energy.mean()
E2 = NewC.energy.mean()
L1 = OldC.loudness.mean()
L2 = NewC.loudness.mean()
Li1 = OldC.liveness.mean()
Li2 = NewC.liveness.mean()
S1 = OldC.speechiness.mean()
S2 = NewC.speechiness.mean()
A1 = OldC.acousticness.mean()
A2 = NewC.acousticness.mean()
I1 = OldC.instrumentalness.mean()
I2 = NewC.instrumentalness.mean()

if(D1<D2):
    print("Danceability match: True")
else:
    print("Danceability match: False")

if(E1>E2):
    print("energy match: True")
else:
    print("energy match: False")

if(L1>L2):
    print("Loudness match: True")
else:
    print("Loudness match: False")

if(Li1<Li2):
    print("Liveness match: True")
else:
    print("Liveness match: False")
    
if(S1<S2):
    print("Speechiness match: True")
else:
    print("Speechiness match: False")
    
if(A1<A2):
    print("Acousticness match: True")
else:
    print("Acousticness match: False")
    
if(I1>I2):
    print("Instrumentalness match: True")
else:
    print("Instrumentalness match: False")

print("")
print("")
# Out:
# Drake
# Danceability match: False
# energy match: False
# Loudness match: False
# Liveness match: True
# Speechiness match: False
# Acousticness match: False
# Instrumentalness match: True
#
#
# Maroon 5
# Danceability match: True
# energy match: True
# Loudness match: False
# Liveness match: True
# Speechiness match: False
# Acousticness match: True
# Instrumentalness match: False
#
#
# Calvin Harris
# Danceability match: False
# energy match: False
# Loudness match: True
# Liveness match: True
# Speechiness match: True
# Acousticness match: False
# Instrumentalness match: False
